# %%
from __future__ import print_function
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <div class="info">
# PH2150-  Scientific Computing and Employabilty Skills
#
# ### Chapter 4: Control Structures (*<font color='green'>if, else, elif,for, while</font>*)
#
#
# ### Dr. Andrew Casey  (a.casey@rhul.ac.uk, W054)
#
# In general, statements are executed sequentially, top to bottom.
# There are many instances when you want to break away from this e.g,
#
# * **Branch point**: choose to go in one direction or another based on meeting some condition.
# * **Repeat:** You may want to execute a block of code several times.
#
# Programming languages provide various control structures that allow for more complicated execution paths.
# Here we will use conditionals and loops:
#
# * **if**
# * **else**
# * **elif**
# * **for**
# * **while**
#
# In addition the following functions are useful for control structures,
# * **range**
# * **break**
# * **continue**

# %% [markdown]
# ### Control Structures: Boolean Variable type (<font color='green'>True of False</font>).
#
# **Variable type** – *Boolean* (True or False)
#
#
# * $==$ is the equivalent to operator. Returns true if both operands are the same.
#
# * $!=$ is not equal to operator. True if both the operands are not equal else False.
#
# * $>$ is greater than operator. True if the first operand is greater than the second operand.
# * $>=$ is greater than or equal to operator. True if the first operand is greater than or equal to the second operand.
#
# Similarly, $<$ and $<=$ are less than and less than or equal to operators.
#
# Combined with the logical operators *<font color='green'>and, or, not</font>* allows more complex conditional statements.

# %%
x=2
print(x==3) # Is x equivalent to 3?
print(x>=1 and x<3) # combination of operators
# Out:
# False
# True

# %% [markdown]
# ## The *if* statement
#
# The *if* statement is used to check a condition: if the condition is TRUE, we run a block of statements (the if-block), else (FALSE) we process another block of statements (else-block) or continue if no optional else clause.
#
# **if** guess == number:  # 1st condition
#
#     <Block of statements> # the if block if condition is TRUE (note indented)
#
# **else:**
#
#     <Block of statements> # the else block if condition is FALSE (note indented)
#
# After running either block of statements you drop back into the main programme.

# %% [markdown]
# ## The *if* statement
# <img src="attachment:if_else.jpg" style="max-width:100%">

# %% [markdown]
# ## The *elif* statement
# The *elif* statement allows you to check multiple expressions for TRUE and execute a block of code as soon as one of the conditions evaluates to TRUE..
#
# <img src="attachment:elif.jpg" style="max-width:100%">

# %% [markdown]
# ### *if* and *elif* examples

# %%
x=[1,2,3,4,5]
if len(x)<10: # if this condition is true run the idented block of statements
    print(x) # block of statements
    print(x[3])
    print('length of x =',len(x)) # when you reach the end of the block the if statement is finsished
# Out:
# [1, 2, 3, 4, 5]
# 4
# length of x = 5

# %%
x = int(input("Please enter an integer: "))
if x < 0:
    x = 0
    print('Negative changed to zero')
elif x == 0:
    print('Zero')
elif x == 1:
    print('single')
else:
    print('More')
# Out:
# Please enter an integer:  0
# Zero

# %% [markdown]
# ## The *for* loop
#
# Loops:  *for* loops are traditionally used when you have a piece of code which you want to repeat a number of times. As an alternative, there is the *while* Loop, the *while* loop is used when a condition is to be met, or if you want a piece of code to repeat until intrupted by another event.

# %% [markdown]
# ## *for* flowchart
#
# <img src="attachment:for_loop.jpg" style="max-width:100%">
#
#
# Iterating over all the values in a sequence

# %%
print('Part 1:')

for letter in 'Python':     # loops for each character in string
    print( 'Current Letter :', letter)

print('Part 2:')
fruits = ['banana', 'apple',  'mango']
for fruit in fruits:        # loops for each element in list
    print ('Current fruit :', fruit)

print('Part 3:')
for index in range(len(fruits)): # loops for each element in list
    print ('Current fruit :', fruits[index])

print('Part 4:')
FruitsA=[x for x in fruits if x[0]=='a'] # returns [‘apple’], this is known as list comprehension.

print(FruitsA)
# Out:
# Part 1:
# Current Letter : P
# Current Letter : y
# Current Letter : t
# Current Letter : h
# Current Letter : o
# Current Letter : n
# Part 2:
# Current fruit : banana
# Current fruit : apple
# Current fruit : mango
# Part 3:
# Current fruit : banana
# Current fruit : apple
# Current fruit : mango
# Part 4:
# ['apple']

# %% [markdown]
# ## *for* flowchart
#
# You can combine *for* loops with *if* statements to create a conditional *for* loop, but this is where the *while* loop is usually employed
#
# <img src="attachment:fornext_loop.jpg" style="max-width:100%">
#
# Incrementing a *for* loop until a conditional statement is met

# %%
#while expression: #while TRUE execute block of statements
#<Block of statements> 

var = 1
while var == 1 :  # This constructs an infinite loop
    num = input("Enter a number  :")
    print( "You entered: ", num)

    if num=='Q': # This gives a route out of loop
        print ('Goodbye')
        break # break will terminate the loop
# Out:
# Enter a number  : 2
# Enter a number  :
# You entered:  2
# Enter a number  :
# You entered:  3
# You entered:  4
# Enter a number  : Q
# You entered:  Q
# Goodbye

# %% [markdown]
# ## *while* flowchart
#
# <img src="attachment:while_loop.jpg" style="max-width:100%">
#
# Continue until condition is FALSE.

# %% [markdown]
# ## Next Step
#
# Now you can move on [chapter 5](PH2150_lecture5.ipynb) or return to the [menu](PH2150_Start_here.ipynb)
